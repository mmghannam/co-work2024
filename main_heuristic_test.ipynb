# %%
from vrppd_parameters import Parameters
from vrppd_solution import Solution
#from random_greedy_courier_heuristic import random_greedy_courier_heuristic
#from heuristic_generator import random_greedy_courier_heuristic
import heuristic_generator
from stack_deliveries_in_route import stack_deliveries_in_route
import time
import numpy as np
import is_feasible
import read_data
import matplotlib.pyplot as plt
import write_solution

#print(dir(heuristic_generator))

all_instances = read_data.read_all_instances_from_folder('Challenge/training_data')

for index in range(0, len(all_instances)):
    test_parameters = Parameters(all_instances[index])

    best_solution = Solution(test_parameters)

    print('#################')
    #print(f'Instance {test_parameters.instance_name}')
    print(f'courier_count: {test_parameters.courier_count}, delivery_count: {test_parameters.delivery_count}')

    total_delivery_times_before = []
    total_delivery_times_after = []

    time_start = time.time()
    for i in range(0, 1):
        incumbent_solution = Solution(test_parameters)
        heuristic_generator.random_greedy_courier_heuristic(test_parameters, incumbent_solution)
        total_delivery_times_before.append(incumbent_solution.total_delivery_time)
        stack_deliveries_in_route(test_parameters, incumbent_solution)
        total_delivery_times_after.append(incumbent_solution.total_delivery_time)
        if not is_feasible.is_feasible(test_parameters, incumbent_solution):
            break
        if incumbent_solution.total_delivery_time < best_solution.total_delivery_time:
            best_solution = incumbent_solution
        
    time_end = time.time()
    instance_name = all_instances[index]['instance_name']
    write_solution.write_solution_to_csv(best_solution, f'solutions/{instance_name}.txt')
    

    print(f'Best solution found: {best_solution.total_delivery_time} with time {time_end - time_start} seconds')
    print(f'Average solution found: {np.mean(total_delivery_times_after)}')
# Out:
# #################
# courier_count: 281, delivery_count: 439
# Time window of delivery 320 is violated
# Best solution found: 9.223372036854776e+18 with time 4.304985046386719 seconds
# Average solution found: 12578.0
# #################
# courier_count: 503, delivery_count: 484
# Time window of delivery 82 is violated
# Time window of delivery 95 is violated
# Time window of delivery 102 is violated
# Time window of delivery 113 is violated
# Time window of delivery 183 is violated
# Time window of delivery 203 is violated
# Time window of delivery 336 is violated
# Best solution found: 9.223372036854776e+18 with time 8.89136004447937 seconds
# Average solution found: 17505.0
# #################
# courier_count: 3, delivery_count: 11
# Capacity of courier 3 is exceeded
# Capacity of courier 3 is exceeded
# Capacity of courier 3 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.1455397605895996 seconds
# Average solution found: 350.0
# #################
# courier_count: 397, delivery_count: 307
# Best solution found: 9953.0 with time 3.956240177154541 seconds
# Average solution found: 9953.0
# #################
# courier_count: 54, delivery_count: 37
# Best solution found: 1212.0 with time 0.07989192008972168 seconds
# Average solution found: 1212.0
# #################
# courier_count: 27, delivery_count: 32
# Best solution found: 945.0 with time 0.050499916076660156 seconds
# Average solution found: 945.0
# #################
# courier_count: 1, delivery_count: 2
# Best solution found: 42.0 with time 0.0003178119659423828 seconds
# Average solution found: 42.0
# #################
# courier_count: 64, delivery_count: 73
# Capacity of courier 8 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.22525405883789062 seconds
# Average solution found: 1394.0
# #################
# courier_count: 1, delivery_count: 1
# Best solution found: 25.0 with time 0.00011801719665527344 seconds
# Average solution found: 25.0
# #################
# courier_count: 8, delivery_count: 9
# Best solution found: 167.0 with time 0.0026438236236572266 seconds
# Average solution found: 167.0
# #################
# courier_count: 5, delivery_count: 14
# Best solution found: 395.0 with time 0.01727914810180664 seconds
# Average solution found: 395.0
# #################
# courier_count: 16, delivery_count: 26
# Best solution found: 702.0 with time 0.019553661346435547 seconds
# Average solution found: 702.0
# #################
# courier_count: 358, delivery_count: 330
# Time window of delivery 252 is violated
# Time window of delivery 265 is violated
# Time window of delivery 314 is violated
# Capacity of courier 114 is exceeded
# Capacity of courier 151 is exceeded
# Best solution found: 9.223372036854776e+18 with time 3.3506202697753906 seconds
# Average solution found: 13219.0
# #################
# courier_count: 391, delivery_count: 345
# Time window of delivery 155 is violated
# Time window of delivery 263 is violated
# Best solution found: 9.223372036854776e+18 with time 3.9943530559539795 seconds
# Average solution found: 9954.0
# #################
# courier_count: 2, delivery_count: 2
# Best solution found: 73.0 with time 0.0005543231964111328 seconds
# Average solution found: 73.0
# #################
# courier_count: 9, delivery_count: 8
# Best solution found: 247.0 with time 0.002621889114379883 seconds
# Average solution found: 247.0
# #################
# courier_count: 25, delivery_count: 24
# Best solution found: 460.0 with time 0.03254508972167969 seconds
# Average solution found: 460.0
# #################
# courier_count: 4, delivery_count: 4
# Best solution found: 77.0 with time 0.0007810592651367188 seconds
# Average solution found: 77.0
# #################
# courier_count: 413, delivery_count: 377
# Time window of delivery 8 is violated
# Time window of delivery 90 is violated
# Best solution found: 9.223372036854776e+18 with time 4.630367994308472 seconds
# Average solution found: 18132.0
# #################
# courier_count: 30, delivery_count: 34
# Best solution found: 884.0 with time 0.03730607032775879 seconds
# Average solution found: 884.0
# #################
# courier_count: 524, delivery_count: 397
# Time window of delivery 202 is violated
# Time window of delivery 351 is violated
# Time window of delivery 370 is violated
# Best solution found: 9.223372036854776e+18 with time 6.414389133453369 seconds
# Average solution found: 14846.0
# #################
# courier_count: 25, delivery_count: 17
# Best solution found: 294.0 with time 0.014810800552368164 seconds
# Average solution found: 294.0
# #################
# courier_count: 162, delivery_count: 147
# Time window of delivery 93 is violated
# Best solution found: 9.223372036854776e+18 with time 0.73649001121521 seconds
# Average solution found: 4444.0
# #################
# courier_count: 402, delivery_count: 545
# Time window of delivery 44 is violated
# Time window of delivery 140 is violated
# Time window of delivery 237 is violated
# Time window of delivery 246 is violated
# Time window of delivery 251 is violated
# Time window of delivery 393 is violated
# Time window of delivery 438 is violated
# Time window of delivery 502 is violated
# Time window of delivery 521 is violated
# Capacity of courier 282 is exceeded
# Best solution found: 9.223372036854776e+18 with time 7.32928729057312 seconds
# Average solution found: 30651.0
# #################
# courier_count: 1, delivery_count: 1
# Best solution found: 11.0 with time 0.001194000244140625 seconds
# Average solution found: 11.0
# #################
# courier_count: 4, delivery_count: 6
# Best solution found: 155.0 with time 0.0014760494232177734 seconds
# Average solution found: 155.0
# #################
# courier_count: 8, delivery_count: 5
# Best solution found: 88.0 with time 0.002312183380126953 seconds
# Average solution found: 88.0
# #################
# courier_count: 817, delivery_count: 630
# Time window of delivery 46 is violated
# Time window of delivery 403 is violated
# Time window of delivery 628 is violated
# Best solution found: 9.223372036854776e+18 with time 15.642916202545166 seconds
# Average solution found: 25322.0
# #################
# courier_count: 23, delivery_count: 36
# Best solution found: 951.0 with time 0.024801015853881836 seconds
# Average solution found: 951.0
# #################
# courier_count: 295, delivery_count: 322
# Time window of delivery 103 is violated
# Time window of delivery 111 is violated
# Capacity of courier 31 is exceeded
# Capacity of courier 64 is exceeded
# Capacity of courier 72 is exceeded
# Best solution found: 9.223372036854776e+18 with time 3.143545150756836 seconds
# Average solution found: 16147.0
# #################
# courier_count: 131, delivery_count: 150
# Capacity of courier 84 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.6895802021026611 seconds
# Average solution found: 3695.0
# #################
# courier_count: 75, delivery_count: 35
# Best solution found: 835.0 with time 0.07995009422302246 seconds
# Average solution found: 835.0
# #################
# courier_count: 8, delivery_count: 8
# Best solution found: 302.0 with time 0.005891084671020508 seconds
# Average solution found: 302.0
# #################
# courier_count: 771, delivery_count: 1223
# Time window of delivery 46 is violated
# Time window of delivery 211 is violated
# Time window of delivery 478 is violated
# Time window of delivery 593 is violated
# Time window of delivery 608 is violated
# Time window of delivery 1038 is violated
# Capacity of courier 569 is exceeded
# Best solution found: 9.223372036854776e+18 with time 24.285219192504883 seconds
# Average solution found: 33803.0
# #################
# courier_count: 39, delivery_count: 34
# Best solution found: 890.0 with time 0.02538919448852539 seconds
# Average solution found: 890.0
# #################
# courier_count: 30, delivery_count: 25
# Best solution found: 578.0 with time 0.01577901840209961 seconds
# Average solution found: 578.0
# #################
# courier_count: 27, delivery_count: 13
# Best solution found: 511.0 with time 0.006679058074951172 seconds
# Average solution found: 511.0
# #################
# courier_count: 572, delivery_count: 479
# Time window of delivery 264 is violated
# Time window of delivery 270 is violated
# Best solution found: 9.223372036854776e+18 with time 5.2442991733551025 seconds
# Average solution found: 15674.0
# #################
# courier_count: 1379, delivery_count: 608
# Best solution found: 24579.0 with time 14.209131956100464 seconds
# Average solution found: 24579.0
# #################
# courier_count: 4, delivery_count: 6
# Best solution found: 137.0 with time 0.0016369819641113281 seconds
# Average solution found: 137.0
# #################
# courier_count: 217, delivery_count: 225
# Time window of delivery 35 is violated
# Time window of delivery 50 is violated
# Time window of delivery 59 is violated
# Best solution found: 9.223372036854776e+18 with time 0.9518218040466309 seconds
# Average solution found: 11013.0
# #################
# courier_count: 9, delivery_count: 8
# Best solution found: 158.0 with time 0.0022590160369873047 seconds
# Average solution found: 158.0
# #################
# courier_count: 729, delivery_count: 923
# Time window of delivery 1 is violated
# Time window of delivery 491 is violated
# Best solution found: 9.223372036854776e+18 with time 14.117046117782593 seconds
# Average solution found: 23565.0
# #################
# courier_count: 4, delivery_count: 4
# Best solution found: 113.0 with time 0.0006241798400878906 seconds
# Average solution found: 113.0
# #################
# courier_count: 2, delivery_count: 4
# Best solution found: 116.0 with time 0.0005681514739990234 seconds
# Average solution found: 116.0
# #################
# courier_count: 29, delivery_count: 27
# Best solution found: 490.0 with time 0.016787052154541016 seconds
# Average solution found: 490.0
# #################
# courier_count: 4, delivery_count: 5
# Best solution found: 109.0 with time 0.0008008480072021484 seconds
# Average solution found: 109.0
# #################
# courier_count: 10, delivery_count: 7
# Best solution found: 155.0 with time 0.002248048782348633 seconds
# Average solution found: 155.0
# #################
# courier_count: 8, delivery_count: 11
# Best solution found: 566.0 with time 0.002794027328491211 seconds
# Average solution found: 566.0
# #################
# courier_count: 91, delivery_count: 85
# Time window of delivery 17 is violated
# Best solution found: 9.223372036854776e+18 with time 0.14763283729553223 seconds
# Average solution found: 4278.0
# #################
# courier_count: 2, delivery_count: 13
# Best solution found: 720.0 with time 0.0025331974029541016 seconds
# Average solution found: 720.0
# #################
# courier_count: 74, delivery_count: 50
# Best solution found: 44912.0 with time 0.06960010528564453 seconds
# Average solution found: 44912.0
# #################
# courier_count: 132, delivery_count: 371
# Time window of delivery 59 is violated
# Best solution found: 9.223372036854776e+18 with time 2.3153417110443115 seconds
# Average solution found: 10851.0
# #################
# courier_count: 108, delivery_count: 135
# Best solution found: 3596.0 with time 0.30893611907958984 seconds
# Average solution found: 3596.0
# #################
# courier_count: 590, delivery_count: 623
# Time window of delivery 107 is violated
# Capacity of courier 122 is exceeded
# Capacity of courier 246 is exceeded
# Capacity of courier 342 is exceeded
# Capacity of courier 377 is exceeded
# Capacity of courier 411 is exceeded
# Capacity of courier 541 is exceeded
# Capacity of courier 556 is exceeded
# Capacity of courier 564 is exceeded
# Capacity of courier 576 is exceeded
# Best solution found: 9.223372036854776e+18 with time 7.12212872505188 seconds
# Average solution found: 19626.0
# #################
# courier_count: 129, delivery_count: 70
# Best solution found: 2603.0 with time 0.14845895767211914 seconds
# Average solution found: 2603.0
# #################
# courier_count: 29, delivery_count: 27
# Best solution found: 956.0 with time 0.017818927764892578 seconds
# Average solution found: 956.0
# #################
# courier_count: 2, delivery_count: 5
# Best solution found: 201.0 with time 0.0010478496551513672 seconds
# Average solution found: 201.0
# #################
# courier_count: 6, delivery_count: 5
# Best solution found: 79.0 with time 0.0009598731994628906 seconds
# Average solution found: 79.0
# #################
# courier_count: 52, delivery_count: 54
# Best solution found: 3332.0 with time 0.06143617630004883 seconds
# Average solution found: 3332.0
# #################
# courier_count: 251, delivery_count: 259
# Best solution found: 5023.0 with time 1.2615487575531006 seconds
# Average solution found: 5023.0
# #################
# courier_count: 8, delivery_count: 8
# Best solution found: 220.0 with time 0.0020029544830322266 seconds
# Average solution found: 220.0
# #################
# courier_count: 16, delivery_count: 14
# Best solution found: 466.0 with time 0.005513906478881836 seconds
# Average solution found: 466.0
# #################
# courier_count: 134, delivery_count: 122
# Capacity of courier 5 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.30272722244262695 seconds
# Average solution found: 2674.0
# #################
# courier_count: 300, delivery_count: 510
# Time window of delivery 21 is violated
# Time window of delivery 57 is violated
# Time window of delivery 81 is violated
# Time window of delivery 253 is violated
# Time window of delivery 475 is violated
# Capacity of courier 10 is exceeded
# Capacity of courier 29 is exceeded
# Capacity of courier 39 is exceeded
# Capacity of courier 234 is exceeded
# Best solution found: 9.223372036854776e+18 with time 4.198742628097534 seconds
# Average solution found: 13682.0
# #################
# courier_count: 76, delivery_count: 96
# Best solution found: 5057.0 with time 0.1663069725036621 seconds
# Average solution found: 5057.0
# #################
# courier_count: 4, delivery_count: 3
# Best solution found: 54.0 with time 0.00044798851013183594 seconds
# Average solution found: 54.0
# #################
# courier_count: 3, delivery_count: 5
# Best solution found: 145.0 with time 0.0007309913635253906 seconds
# Average solution found: 145.0
# #################
# courier_count: 3, delivery_count: 3
# Best solution found: 196.0 with time 0.00038814544677734375 seconds
# Average solution found: 196.0
# #################
# courier_count: 10, delivery_count: 17
# Best solution found: 484.0 with time 0.006000995635986328 seconds
# Average solution found: 484.0
# #################
# courier_count: 3, delivery_count: 6
# Best solution found: 252.0 with time 0.0012202262878417969 seconds
# Average solution found: 252.0
# #################
# courier_count: 518, delivery_count: 643
# Time window of delivery 25 is violated
# Time window of delivery 41 is violated
# Time window of delivery 197 is violated
# Time window of delivery 237 is violated
# Capacity of courier 268 is exceeded
# Best solution found: 9.223372036854776e+18 with time 6.901284694671631 seconds
# Average solution found: 12441.0
# #################
# courier_count: 268, delivery_count: 324
# Best solution found: 10070.0 with time 1.7732949256896973 seconds
# Average solution found: 10070.0
# #################
# courier_count: 115, delivery_count: 92
# Time window of delivery 35 is violated
# Best solution found: 9.223372036854776e+18 with time 0.22702407836914062 seconds
# Average solution found: 2721.0
# #################
# courier_count: 9, delivery_count: 17
# Best solution found: 503.0 with time 0.006824016571044922 seconds
# Average solution found: 503.0
# #################
# courier_count: 104, delivery_count: 146
# Time window of delivery 95 is violated
# Time window of delivery 139 is violated
# Capacity of courier 56 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.34665393829345703 seconds
# Average solution found: 3371.0
# #################
# courier_count: 3, delivery_count: 5
# Time window of delivery 1 is violated
# Best solution found: 9.223372036854776e+18 with time 0.0008900165557861328 seconds
# Average solution found: 230.0
# #################
# courier_count: 767, delivery_count: 582
# Time window of delivery 80 is violated
# Time window of delivery 259 is violated
# Best solution found: 9.223372036854776e+18 with time 8.55796480178833 seconds
# Average solution found: 26625.0
# #################
# courier_count: 84, delivery_count: 59
# Best solution found: 1859.0 with time 0.0864260196685791 seconds
# Average solution found: 1859.0
# #################
# courier_count: 4, delivery_count: 9
# Best solution found: 267.0 with time 0.005872011184692383 seconds
# Average solution found: 267.0
# #################
# courier_count: 164, delivery_count: 301
# Time window of delivery 1 is violated
# Time window of delivery 256 is violated
# Best solution found: 9.223372036854776e+18 with time 1.5612080097198486 seconds
# Average solution found: 9207.0
# #################
# courier_count: 26, delivery_count: 21
# Best solution found: 514.0 with time 0.010658740997314453 seconds
# Average solution found: 514.0
# #################
# courier_count: 109, delivery_count: 139
# Capacity of courier 10 is exceeded
# Capacity of courier 16 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.3285868167877197 seconds
# Average solution found: 3090.0
# #################
# courier_count: 3, delivery_count: 4
# Best solution found: 145.0 with time 0.0005800724029541016 seconds
# Average solution found: 145.0
# #################
# courier_count: 7, delivery_count: 7
# Best solution found: 100.0 with time 0.0014719963073730469 seconds
# Average solution found: 100.0
# #################
# courier_count: 16, delivery_count: 13
# Best solution found: 219.0 with time 0.004282236099243164 seconds
# Average solution found: 219.0
# #################
# courier_count: 100, delivery_count: 106
# Time window of delivery 73 is violated
# Time window of delivery 86 is violated
# Capacity of courier 32 is exceeded
# Capacity of courier 63 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.20777106285095215 seconds
# Average solution found: 2821.0
# #################
# courier_count: 5, delivery_count: 3
# Best solution found: 49.0 with time 0.0005519390106201172 seconds
# Average solution found: 49.0
# #################
# courier_count: 21, delivery_count: 13
# Best solution found: 455.0 with time 0.0062541961669921875 seconds
# Average solution found: 455.0
# #################
# courier_count: 29, delivery_count: 29
# Best solution found: 635.0 with time 0.019602060317993164 seconds
# Average solution found: 635.0
# #################
# courier_count: 9, delivery_count: 8
# Best solution found: 121.0 with time 0.0018978118896484375 seconds
# Average solution found: 121.0
# #################
# courier_count: 14, delivery_count: 18
# Best solution found: 420.0 with time 0.006844997406005859 seconds
# Average solution found: 420.0
# #################
# courier_count: 1, delivery_count: 1
# Best solution found: 35.0 with time 8.893013000488281e-05 seconds
# Average solution found: 35.0
# #################
# courier_count: 3, delivery_count: 7
# Best solution found: 145.0 with time 0.0014607906341552734 seconds
# Average solution found: 145.0
# #################
# courier_count: 1, delivery_count: 1
# Best solution found: 16.0 with time 0.0001499652862548828 seconds
# Average solution found: 16.0
# #################
# courier_count: 76, delivery_count: 84
# Time window of delivery 4 is violated
# Best solution found: 9.223372036854776e+18 with time 0.13324499130249023 seconds
# Average solution found: 2013.0
# #################
# courier_count: 181, delivery_count: 214
# Time window of delivery 107 is violated
# Time window of delivery 170 is violated
# Best solution found: 9.223372036854776e+18 with time 0.8088109493255615 seconds
# Average solution found: 4872.0
# #################
# courier_count: 4, delivery_count: 3
# Best solution found: 66.0 with time 0.0005040168762207031 seconds
# Average solution found: 66.0
# #################
# courier_count: 66, delivery_count: 67
# Best solution found: 1553.0 with time 0.08902883529663086 seconds
# Average solution found: 1553.0
# #################
# courier_count: 1273, delivery_count: 745
# Time window of delivery 45 is violated
# Time window of delivery 684 is violated
# Time window of delivery 745 is violated
# Best solution found: 9.223372036854776e+18 with time 14.44507908821106 seconds
# Average solution found: 23988.0
# #################
# courier_count: 37, delivery_count: 58
# Best solution found: 1643.0 with time 0.0574641227722168 seconds
# Average solution found: 1643.0
# #################
# courier_count: 912, delivery_count: 541
# Time window of delivery 243 is violated
# Best solution found: 9.223372036854776e+18 with time 8.935094594955444 seconds
# Average solution found: 24241.0
# #################
# courier_count: 104, delivery_count: 170
# Best solution found: 4049.0 with time 0.44614696502685547 seconds
# Average solution found: 4049.0
# #################
# courier_count: 4, delivery_count: 5
# Best solution found: 131.0 with time 0.0008831024169921875 seconds
# Average solution found: 131.0
# #################
# courier_count: 333, delivery_count: 401
# Time window of delivery 161 is violated
# Time window of delivery 205 is violated
# Capacity of courier 39 is exceeded
# Capacity of courier 95 is exceeded
# Capacity of courier 145 is exceeded
# Capacity of courier 165 is exceeded
# Capacity of courier 225 is exceeded
# Capacity of courier 225 is exceeded
# Capacity of courier 225 is exceeded
# Capacity of courier 242 is exceeded
# Capacity of courier 305 is exceeded
# Capacity of courier 313 is exceeded
# Capacity of courier 329 is exceeded
# Best solution found: 9.223372036854776e+18 with time 3.212878942489624 seconds
# Average solution found: 10407.0
# #################
# courier_count: 4, delivery_count: 2
# Best solution found: 135.0 with time 0.0002751350402832031 seconds
# Average solution found: 135.0
# #################
# courier_count: 30, delivery_count: 5
# Best solution found: 80.0 with time 0.0027599334716796875 seconds
# Average solution found: 80.0
# #################
# courier_count: 6, delivery_count: 16
# Best solution found: 378.0 with time 0.00908207893371582 seconds
# Average solution found: 378.0
# #################
# courier_count: 55, delivery_count: 149
# Time window of delivery 20 is violated
# Time window of delivery 54 is violated
# Time window of delivery 81 is violated
# Time window of delivery 112 is violated
# Capacity of courier 2 is exceeded
# Capacity of courier 5 is exceeded
# Capacity of courier 6 is exceeded
# Capacity of courier 9 is exceeded
# Capacity of courier 14 is exceeded
# Capacity of courier 16 is exceeded
# Capacity of courier 20 is exceeded
# Capacity of courier 23 is exceeded
# Capacity of courier 23 is exceeded
# Capacity of courier 23 is exceeded
# Capacity of courier 29 is exceeded
# Capacity of courier 32 is exceeded
# Capacity of courier 38 is exceeded
# Capacity of courier 41 is exceeded
# Capacity of courier 42 is exceeded
# Capacity of courier 46 is exceeded
# Capacity of courier 47 is exceeded
# Capacity of courier 52 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.32540297508239746 seconds
# Average solution found: 6362.0
# #################
# courier_count: 22, delivery_count: 32
# Time window of delivery 8 is violated
# Best solution found: 9.223372036854776e+18 with time 0.01907801628112793 seconds
# Average solution found: 4727.0
# #################
# courier_count: 19, delivery_count: 14
# Best solution found: 534.0 with time 0.005647897720336914 seconds
# Average solution found: 534.0
# #################
# courier_count: 130, delivery_count: 117
# Best solution found: 2371.0 with time 0.31528806686401367 seconds
# Average solution found: 2371.0
# #################
# courier_count: 10, delivery_count: 20
# Best solution found: 504.0 with time 0.0076732635498046875 seconds
# Average solution found: 504.0
# #################
# courier_count: 147, delivery_count: 155
# Best solution found: 3928.0 with time 0.48891711235046387 seconds
# Average solution found: 3928.0
# #################
# courier_count: 15, delivery_count: 18
# Best solution found: 561.0 with time 0.008140802383422852 seconds
# Average solution found: 561.0
# #################
# courier_count: 37, delivery_count: 43
# Best solution found: 974.0 with time 0.03555607795715332 seconds
# Average solution found: 974.0
# #################
# courier_count: 526, delivery_count: 648
# Time window of delivery 1 is violated
# Time window of delivery 133 is violated
# Time window of delivery 165 is violated
# Time window of delivery 537 is violated
# Capacity of courier 76 is exceeded
# Capacity of courier 85 is exceeded
# Capacity of courier 484 is exceeded
# Best solution found: 9.223372036854776e+18 with time 7.551497936248779 seconds
# Average solution found: 25923.0
# #################
# courier_count: 1, delivery_count: 4
# Best solution found: 128.0 with time 0.004544973373413086 seconds
# Average solution found: 128.0
# #################
# courier_count: 4, delivery_count: 5
# Best solution found: 144.0 with time 0.0008180141448974609 seconds
# Average solution found: 144.0
# #################
# courier_count: 681, delivery_count: 648
# Time window of delivery 208 is violated
# Time window of delivery 452 is violated
# Time window of delivery 471 is violated
# Time window of delivery 523 is violated
# Time window of delivery 550 is violated
# Time window of delivery 564 is violated
# Capacity of courier 574 is exceeded
# Best solution found: 9.223372036854776e+18 with time 7.880413055419922 seconds
# Average solution found: 30342.0
# #################
# courier_count: 5, delivery_count: 6
# Best solution found: 125.0 with time 0.0011892318725585938 seconds
# Average solution found: 125.0
# #################
# courier_count: 114, delivery_count: 97
# Best solution found: 3467.0 with time 0.2308652400970459 seconds
# Average solution found: 3467.0
# #################
# courier_count: 14, delivery_count: 10
# Best solution found: 212.0 with time 0.0031480789184570312 seconds
# Average solution found: 212.0
# #################
# courier_count: 56, delivery_count: 33
# Best solution found: 689.0 with time 0.03278303146362305 seconds
# Average solution found: 689.0
# #################
# courier_count: 371, delivery_count: 446
# Time window of delivery 190 is violated
# Time window of delivery 277 is violated
# Capacity of courier 120 is exceeded
# Capacity of courier 300 is exceeded
# Capacity of courier 300 is exceeded
# Best solution found: 9.223372036854776e+18 with time 3.681972026824951 seconds
# Average solution found: 9875.0
# #################
# courier_count: 4, delivery_count: 6
# Best solution found: 69.0 with time 0.0011060237884521484 seconds
# Average solution found: 69.0
# #################
# courier_count: 131, delivery_count: 88
# Time window of delivery 50 is violated
# Best solution found: 9.223372036854776e+18 with time 0.18698811531066895 seconds
# Average solution found: 1767.0
# #################
# courier_count: 371, delivery_count: 218
# Time window of delivery 45 is violated
# Best solution found: 9.223372036854776e+18 with time 1.5160658359527588 seconds
# Average solution found: 14070.0
# #################
# courier_count: 283, delivery_count: 434
# Time window of delivery 271 is violated
# Time window of delivery 339 is violated
# Best solution found: 9.223372036854776e+18 with time 2.910085916519165 seconds
# Average solution found: 9724.0
# #################
# courier_count: 2, delivery_count: 6
# Best solution found: 89.0 with time 0.004948854446411133 seconds
# Average solution found: 89.0
# #################
# courier_count: 53, delivery_count: 62
# Best solution found: 1881.0 with time 0.07335901260375977 seconds
# Average solution found: 1881.0
# #################
# courier_count: 745, delivery_count: 526
# Time window of delivery 27 is violated
# Best solution found: 9.223372036854776e+18 with time 7.392891883850098 seconds
# Average solution found: 15161.0
# #################
# courier_count: 22, delivery_count: 35
# Capacity of courier 16 is exceeded
# Best solution found: 9.223372036854776e+18 with time 0.027840137481689453 seconds
# Average solution found: 1237.0
# #################
# courier_count: 69, delivery_count: 45
# Best solution found: 1808.0 with time 0.05545186996459961 seconds
# Average solution found: 1808.0
# #################
# courier_count: 13, delivery_count: 11
# Best solution found: 227.0 with time 0.003505229949951172 seconds
# Average solution found: 227.0
# #################
# courier_count: 27, delivery_count: 24
# Best solution found: 451.0 with time 0.014066934585571289 seconds
# Average solution found: 451.0
# #################
# courier_count: 8, delivery_count: 11
# Best solution found: 219.0 with time 0.0030078887939453125 seconds
# Average solution found: 219.0
# #################
# courier_count: 16, delivery_count: 21
# Best solution found: 347.0 with time 0.008714914321899414 seconds
# Average solution found: 347.0
# #################
# courier_count: 45, delivery_count: 53
# Best solution found: 1255.0 with time 0.052848100662231445 seconds
# Average solution found: 1255.0
# #################
# courier_count: 19, delivery_count: 16
# Best solution found: 616.0 with time 0.006674051284790039 seconds
# Average solution found: 616.0
# #################
# courier_count: 26, delivery_count: 12
# Best solution found: 232.0 with time 0.006513118743896484 seconds
# Average solution found: 232.0
# #################
# courier_count: 4, delivery_count: 5
# Best solution found: 115.0 with time 0.0008599758148193359 seconds
# Average solution found: 115.0
# #################
# courier_count: 11, delivery_count: 9
# Best solution found: 159.0 with time 0.0025680065155029297 seconds
# Average solution found: 159.0
# #################
# courier_count: 537, delivery_count: 692
# Time window of delivery 495 is violated
# Time window of delivery 572 is violated
# Best solution found: 9.223372036854776e+18 with time 7.786839008331299 seconds
# Average solution found: 21903.0
# #################
# courier_count: 11, delivery_count: 18
# Best solution found: 422.0 with time 0.00726008415222168 seconds
# Average solution found: 422.0
# #################
# courier_count: 1, delivery_count: 2
# Best solution found: 51.0 with time 0.0002498626708984375 seconds
# Average solution found: 51.0
# #################
# courier_count: 15, delivery_count: 15
# Best solution found: 255.0 with time 0.008748769760131836 seconds
# Average solution found: 255.0
# #################
# courier_count: 428, delivery_count: 626
# Time window of delivery 323 is violated
# Best solution found: 9.223372036854776e+18 with time 6.146994113922119 seconds
# Average solution found: 13369.0
# #################
# courier_count: 26, delivery_count: 27
# Best solution found: 526.0 with time 0.018065929412841797 seconds
# Average solution found: 526.0
# #################
# courier_count: 6, delivery_count: 8
# Best solution found: 181.0 with time 0.0018329620361328125 seconds
# Average solution found: 181.0

# %%
from route_list import route_list
import networkx as nx

#print(best_solution.routing_plan)
#print(route_list(test_parameters,best_solution))

distance_matrix = test_parameters.location_distance_matrix

# Create a networkx graph
G = nx.Graph()

# Add nodes to the graph
for location in range(1, test_parameters.location_count + 1):
    G.add_node(location)

# Add edges to the graph with arc lengths from distance_matrix
for i in range(1, test_parameters.location_count + 1):
    for j in range(i + 1, test_parameters.location_count + 1):
        distance = distance_matrix[i-1][j-1]
        G.add_edge(i, j, weight=distance)

# Draw the graph
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G, pos, node_size=10)

# Draw the routes specified in route_list
print(route_list(test_parameters, best_solution))
edges = []
for route in route_list(test_parameters, best_solution):
    if len(route) > 1:
        #print(route)
        for i in range(len(route)-1):
            #print((route[i], route[i + 1]))
            edges.append((route[i]+1, route[i + 1]+1))

#print(edges)

# Check if the nodes in the edges list exist in the graph
print(edges)
#edges = [(u, v) for u, v in edges if u in G.nodes and v in G.nodes]

nx.draw_networkx_edges(G, pos, edgelist=edges, edge_color='r', width=2, arrows=True, arrowsize=100)  

# Show the graph
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 23
#      20         G.add_edge(i, j, weight=distance)
#      22 # Draw the graph
# ---> 23 pos = nx.spring_layout(G)
#      24 nx.draw_networkx_nodes(G, pos, node_size=10)
#      26 # Draw the routes specified in route_list
#
# File /usr/local/lib/python3.9/site-packages/networkx/utils/decorators.py:770, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     769 def func(*args, __wrapper=None, **kwargs):
# --> 770     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 4:4, in argmap_spring_layout_1(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /usr/local/lib/python3.9/site-packages/networkx/drawing/layout.py:482, in spring_layout(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed)
#     480         nnodes, _ = A.shape
#     481         k = dom_size / np.sqrt(nnodes)
# --> 482     pos = _sparse_fruchterman_reingold(
#     483         A, k, pos_arr, fixed, iterations, threshold, dim, seed
#     484     )
#     485 except ValueError:
#     486     A = nx.to_numpy_array(G, weight=weight)
#
# File /usr/local/lib/python3.9/site-packages/networkx/utils/decorators.py:770, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     769 def func(*args, __wrapper=None, **kwargs):
# --> 770     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 8:4, in argmap__sparse_fruchterman_reingold_5(A, k, pos, fixed, iterations, threshold, dim, seed)
#       2 import collections
#       3 import gzip
# ----> 4 import inspect
#       5 import itertools
#       6 import re
#
# File /usr/local/lib/python3.9/site-packages/networkx/drawing/layout.py:623, in _sparse_fruchterman_reingold(A, k, pos, fixed, iterations, threshold, dim, seed)
#     621     Ai = A.getrowview(i).toarray()  # TODO: revisit w/ sparse 1D container
#     622     # displacement "force"
# --> 623     displacement[:, i] += (
#     624         delta * (k * k / distance**2 - Ai * distance / k)
#     625     ).sum(axis=1)
#     626 # update positions
#     627 length = np.sqrt((displacement**2).sum(axis=0))
#
# File /usr/local/lib/python3.9/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
